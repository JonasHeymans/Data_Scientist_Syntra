# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Exercise 1
# Create a simple line plot using `plt.plot()` with the following data: `x = [1, 2, 3, 4]` and `y = [1, 4, 9, 16]`. Add grid lines to the plot.

# %% [markdown]
# ### Exercise 2
# Now, recreate the same plot using the object-oriented approach with `fig, ax = plt.subplots()` and compare the difference between the two methods.

# %% [markdown]
# ### Exercise 3
# Generate a plot with two lines representing $y = x$ and $y = x^2$.
# Label the axes as 'Input' and 'Output', and add a title 'Simple Plot'. Include a legend to differentiate between the two lines.

# %% [markdown]
# ### Exercise 4
# Create a scatter plot using random data. Label the x-axis as 'Random X', the y-axis as 'Random Y', and give the plot the title 'Random Scatter Plot'. Position the legend in the upper left corner outside the plot.

# %% [markdown]
# ### Exercise 5
# Plot three different sine waves with different frequencies on the same plot. Use labels and a legend to indicate the frequency of each sine wave. Customize the legend to have a shadow. Also remove the top and right spines.

# %% [markdown]
# ### Exercise 6
# Plot a single line with darkred color, diamond markers, and a dashed line style. Use the following data: x = range(10), y = range(10).

# %% [markdown]
# ### Exercise 7
# Create a plot with three different lines, each with a unique combination of color, marker, and line style. Use any data of your choice and include a legend. Also remove the top and right spines.

# %% [markdown]
# ### Exercise 8
# Generate a scatter plot with points of varying colors and sizes. Map the color to the x value (with colormap ) and the size to the y value of each point. Also remove the top and right spines

# %% [markdown]
# ### Exercise 9
# Create a smooth plot of the function $y = x^3 - x^2$ and set the x-axis limits to [0, 7] and y-axis limits to [-1, 20]. Place markers at all even numbers on the x axis and only show the $y$ ticks that correspond to an $x$ tick that is also shown (i.e. where $x$ is even). Additionally: draw vertical/horizontal lines from the $x$ & $y$ ticks to the corresponding point on the graph.

# %%
# Out:
# 0 0
# 2 4
# 4 48
# 6 180
# (-1.0, 200.0)

# %% [markdown]
# ### Exercise 10
# Plot a curve of the exponential function. Set the $y$-axis to a logarithmic scale and label the ticks with their corresponding exponential values. Set the $x$-axis to $[0, 10]$.

# %% [markdown]
# ### Exercise 11
# Create a bar chart representing the average score of students in a class. Use the following data: `names = ['Alice', 'Bob', 'Charlie', 'Diana']`, `scores = [85, 90, 78, 88]`.

# %%
# Out:
# []

# %% [markdown]
# ### Exercise 12
# Make the same bar chart as in previous exercise but now the horizontal version.

# %%
# Out:
# []

# %% [markdown]
# ### Exercise 13
# Create a figure with four subplots arranged in a 2x2 grid. Plot different mathematical functions (linear, quadratic, cubic, and exponential) in each subplot.

# %% [markdown]
# ### Exercise 14
# Generate a 1x3 grid of subplots with x-axis ranging from 0 to $2\cdot \pi$. Plot a sine wave with different frequencies in each subplot.

# %% [markdown]
# ### Exercise 15
# Write a script that produces a figure with two subplots.
#  1. The first subplot is a line graph showing the values of a normally distributed dataset.
#  2. The second subplot is a histogram of the same data, showing the distribution of the data across different bins.
# The `np.random.normal` can be used to generate random numbers following a normal distribution with a mean (mu) equal to 0 and a standard deviation (sigma) of 0.1.

# %% [markdown]
# ### Exercise 16
# Create any plot of your choice and save it to disk as a PNG file with a resolution of 300 dpi. DPI stands for "dots per inch," representing the resolution or density of dots in an image, indicating the level of detail and clarity in printing or displaying the image.

# %% [markdown]
# ### Exercise 17
# Generate a plot and save it as an SVG file. Experiment with saving the plot with and without the transparent option enabled.
