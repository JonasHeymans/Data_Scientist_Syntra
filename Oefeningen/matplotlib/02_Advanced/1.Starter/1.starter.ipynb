# %% [markdown]
# # Matplotlib — Starter

# %% [markdown]
# **Rules for this notebook**
# - Gebruik de 'nette' manier om matplotlib graphs te maken (object-oriented)
# - Prefer explicit choices (labels, limits, bins, ticks) over defaults.

# %%
import numpy as np
import matplotlib.pyplot as plt

SEED = 42
plt.rcParams.update({
    "figure.dpi": 120,
    "axes.grid": False,
    'figure.figsize':(6,4)
})

# %% [markdown]
# ## 1. Figure vs Axes

# %% [markdown]
# **Task**
# - Create a figure with **two** plot areas next to each other (1 row, 2 columns).
# - Put a different title on each plot area.
# - Make the overall figure a bit wider than default.
#
# **Constraints**
# - Create the layout in one call.
# - Use axes objects (no stateful plotting calls).

# %%
x = np.linspace(0, 2*np.pi, 200)
y1 = np.sin(x)
y2 = np.cos(x)

# %% [markdown]
# ## 2. Line plot

# %% [markdown]
# **Task**
# - Reproduce the line chart output.
# - Add a title and axis labels.
# - Add a legend.
#
# **Constraints**
# - Use two different line styles.
# - Make one line thicker than the other.

# %%
x = np.arange(0, 11)
y1 = x**2
y2 = 2*x + 5

# %% [markdown]
# ## 3. Scatter plot

# %% [markdown]
# **Task**
# - Reproduce the scatter plot output.
# - Show two groups with different markers/colors.
# - Add a legend with exactly two entries (one per group).
#
# **Constraints**
# - Use transparency to reduce overplotting.
# - Legend must correctly describe both groups.

# %%
rng = np.random.default_rng(SEED)

n = 120
x = rng.normal(0, 1, n)
y = 0.7*x + rng.normal(0, 0.7, n)

# %% [markdown]
# ## 4. Bar chart

# %% [markdown]
# **Task**
# - Reproduce the bar chart output.
# - Rotate x tick labels.
#
# **Constraints**
# - Categories must stay in the shown order.
# - Keep a bit of headroom above the tallest bar

# %%
cats = ["A", "B", "C", "D", "E"]
vals = [14, 8, 11, 5, 17]

# %% [markdown]
# ## 5. Histogram

# %% [markdown]
# **Task**
# - Reproduce the histogram output.
# - Use explicit bins.
# - Show the mean as a vertical reference line.
# - Add a legend.
#
# **Constraints**
# - Use a non-default histogram style (not the filled bar default).
# - Y-axis should represent a probability density (not raw counts).

# %%
rng = np.random.default_rng(SEED)

x = rng.normal(loc=0.5, scale=1.2, size=800)

# %% [markdown]
# ## 6. Axes control

# %% [markdown]
# **Task**
# - Reproduce the curve plot output.
# - Use a logarithmic y-axis.
# - Set custom x ticks.
#
# **Constraints**
# - The x-range must be limited to what is shown.
# - Tick labels must be readable (no overlap).

# %%
x = np.linspace(1, 10, 200)
y = np.exp(x/2)

# %% [markdown]
# ## 7. Reference lines & spans

# %% [markdown]
# **Task**
# - Reproduce the plot output.
# - Add a horizontal reference line.
# - Highlight a vertical time window with a translucent band.
#
# **Constraints**
# - The reference line must appear in the legend.
# - The highlighted region must not hide the main line completely.

# %%
rng = np.random.default_rng(SEED)

t = np.arange(0, 31)
signal = 10 + 0.25*t + rng.normal(0, 0.6, size=len(t))
target = 15

# %% [markdown]
# ## 8. Text box

# %% [markdown]
# **Task**
# - Reproduce the chart output.
# - Place a text label near the maximum point.
# - Put the text inside a styled box.
# - Align the text so it looks intentional.
#
# **Constraints**
# - The text should remain attached to the data point when axis limits change.

# %%
rng = np.random.default_rng(SEED)

x = np.linspace(0, 4*np.pi, 250)
y = np.sin(x) + 0.15*rng.normal(size=len(x))

# %% [markdown]
# I## 9. Annotation

# %% [markdown]
# **Task**
# - Reproduce the output.
# - Add an annotation pointing to a specific point.
# - Place the annotation text away from the point and connect it with an arrow.
#
# **Constraints**
# - The arrow must be visible and not overlap the marker.
# - The annotation text must be legible (not on top of the line).

# %%
rng = np.random.default_rng(SEED)

x = np.linspace(0, 10, 200)
y = np.log1p(x) + 0.05*rng.normal(size=len(x))

ix = 140 # Point 140 is the interesting point
