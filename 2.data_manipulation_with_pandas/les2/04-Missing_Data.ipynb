# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'A': [1,3, np.nan],
                   'B': [5, np.nan,np.nan],
                   'C': [1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  3.0  NaN  2
# 2  NaN  NaN  3

# %%
df.isna()
# Out:
# np.int64(3)

# %%
df.isna().sum()
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %%
df.isna().sum(axis=1)
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  3.0  NaN  2

# %%
df.fillna('MISSING')
# Out:
#          A        B  C
# 0      1.0      5.0  1
# 1      3.0  MISSING  2
# 2  MISSING  MISSING  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  3.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(df['A'].mean())
# Out:
# 0    1.0
# 1    3.0
# 2    2.0
# Name: A, dtype: float64

# %%
df.bfill()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  3.0  NaN  2
# 2  NaN  NaN  3

# %%
df = df.dropna()

# %%
def missing_func(rij):
    if rij['A'] == 4:
        return 4
    else:
        return 5

df['A'].apply(lambda x: 1 if x['A'] == 4 else 5)
# Out:
# np.float64(1.0)
