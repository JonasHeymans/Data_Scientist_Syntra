# %% [markdown]
# # Vectorized (String) Operations

# %% [markdown]
# ## 0. Illustratief voorbeeld

# %% [markdown]
# <img src="vectorisation.png" alt="drawing" width="750"/>

# %%
import pandas as pd
import numpy as np
from time import time

# %%
# Sample data: Product prices
prices = np.random.randint(100,1000,9**9)
len(prices)

# %%
# Creating a DataFrame
price_df = pd.DataFrame(prices, columns=['Original_Price'])

# %%
# Vectorization Method

# %%
# Looping Method

# %%
# Displaying the results
print(price_df)

# %% [markdown]
# ## 1. Toy dataset

# %%
toy = pd.DataFrame({
    "name": ["  Alice", "BOB  ", 'Sam', "cHaRlIe", "  dora  ", "Émile", "FRANK", " gina", "Hank ", "  ian"],
    "city": ["Brussels", "antwerp", "gent", 'gent', "Bruges", "brussels", "GENT", "antwerp ", "  bruges", 'bruges'],
    "raw_code": ["A-001", "B_002", "C003", "A-004", 'A-004', "B_006", "C-007", "A_008", "B009", "C_010"],
    "text": [
        "Order #123 shipped",
        "order #124 delayed",
        "REF: 125 shipped",
        "REF: 126 shipped",
        "Order #127 SHIPPED",
        "order 128 cancelled",
        "Ref:129 shipped",
        "Order #130 returned",
        "order #131 shipped",
        "Ref: 132 delayed",
    ],
    "age": [23, 31, 40, 28, 35, 19, 52, 27, 41, 33],
})

# %% [markdown]
# ### Quick frame

# %% [markdown]
# ## 2. Vectorised string operations (`.str`)

# %% [markdown]
# ## 3. Apply
#
# apply is a Python loop disguised as a Pandas method.
#
# It exists to let you run custom Python logic when Pandas has no vectorized alternative.
#
#
# ### When apply is justified
#
# Use apply only when all three are true:
#
# 1. Logic depends on multiple columns
#
# 2. Logic is not expressible via vectorized ops
#
# 3. Performance cost is acceptable (or dataset is small)

# %% [markdown]
# ## 4. `transform`
