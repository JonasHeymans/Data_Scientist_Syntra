# %%
import pandas as pd
import numpy as np
import os
import subprocess

# %%
! python3 --version
! pip3 --version
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.
# pip 25.1.1 from C:\Users\shpctac10027\PycharmProjects\Data_Scientist_Syntra\.venv\Lib\site-packages\pip (python 3.13)

# %%
cur_dir = os.getcwd()
subprocess.call(['python3', f'{cur_dir}/gen_files_io.py'])
# Out:
# 9009

# %%
! pip3 install --upgrade pip
! pip3 install openpyxl
! pip3 install sqlalchemy
! pip3 install psycopg2
! pip3 install fastparquet
! pip3 install lxml
# Out:
# ...
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\shpctac10027\PycharmProjects\Data_Scientist_Syntra\.venv\Scripts\python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# ...

# %%
dconn_str = "postgresql://avnadmin:AVNS_ZdDb93Yjx6l0LlnITsX@pg-230e9f42-jonas-syntra.b.aivencloud.com:23448/defaultdb?sslmode=require"

# %% [markdown]
# 1. CSV-files
# 2. Excel-files
# 3. Parquet files
# 4. SQL Databases

# %% [markdown]
# ## 1. CSV-files
# Comma seperated files

# %% [markdown]
# ### 1.1 Reading
# #### 1.2 Basic cases
# - data inlezen
# - header kiezen
# - index kiezen
# - omgaan met missing data
# - type casting
# - selective reading

# %%
df = pd.read_csv('data/df1.csv')
df.head()
# Out:
#      name  age  score        date  value
# 0    Alex   20     50  01-12-2024    100
# 1   Robin   21     51  02-12-2024    101
# 2     Sam   22     52  03-12-2024    102
# 3   Jamie   23     53  04-12-2024    103
# 4  Taylor   24     54  05-12-2024    104

# %%
pd.read_csv('data/df1.csv', header=1)
# Out:
#       Alex  20  50  01-12-2024  100
# 0    Robin  21  51  02-12-2024  101
# 1      Sam  22  52  03-12-2024  102
# 2    Jamie  23  53  04-12-2024  103
# 3   Taylor  24  54  05-12-2024  104
# 4    Casey  25  55  06-12-2024  105
# 5   Jordan  26  56  07-12-2024  106
# 6      NaN  27  57  08-12-2024  107
# 7    Riley  28  58  09-12-2024  108
# 8  UNKNOWN  29  59  10-12-2024  109

# %%
pd.read_csv('data/df1.csv', usecols=list(range(0,1))+[2])
# Out:
#       name  score
# 0     Alex     50
# 1    Robin     51
# 2      Sam     52
# 3    Jamie     53
# 4   Taylor     54
# 5    Casey     55
# 6   Jordan     56
# 7      NaN     57
# 8    Riley     58
# 9  UNKNOWN     59

# %%
pd.read_csv('data/df1.csv', index_col=0)
# Out:
#          age  score        date  value
# name
# Alex      20     50  01-12-2024    100
# Robin     21     51  02-12-2024    101
# Sam       22     52  03-12-2024    102
# Jamie     23     53  04-12-2024    103
# Taylor    24     54  05-12-2024    104
# Casey     25     55  06-12-2024    105
# Jordan    26     56  07-12-2024    106
# NaN       27     57  08-12-2024    107
# Riley     28     58  09-12-2024    108
# UNKNOWN   29     59  10-12-2024    109

# %%
pd.read_csv('data/df1.csv')
# Out:
#       name  age  score        date  value
# 0     Alex   20     50  01-12-2024    100
# 1    Robin   21     51  02-12-2024    101
# 2      Sam   22     52  03-12-2024    102
# 3    Jamie   23     53  04-12-2024    103
# 4   Taylor   24     54  05-12-2024    104
# 5    Casey   25     55  06-12-2024    105
# 6   Jordan   26     56  07-12-2024    106
# 7      NaN   27     57  08-12-2024    107
# 8    Riley   28     58  09-12-2024    108
# 9  UNKNOWN   29     59  10-12-2024    109

# %%
df = pd.read_csv('data/df1.csv', na_values=['UNKNOWN'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    8 non-null      object
#  1   age     10 non-null     int64
#  2   score   9 non-null      float64
#  3   date    10 non-null     object
#  4   value   10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
test = pd.read_csv('data/df1.csv', dtype={'age':float})

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    9 non-null      object
#  1   age     10 non-null     float64
#  2   score   9 non-null      float64
#  3   date    10 non-null     object
#  4   value   10 non-null     int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 532.0+ bytes

# %%
df_without = pd.read_csv('data/df1.csv')
df_with = pd.read_csv('data/df1.csv', parse_dates=['date'], date_format='%d-%m-%Y')

# %%
df_without.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    9 non-null      object
#  1   age     10 non-null     int64
#  2   score   9 non-null      float64
#  3   date    10 non-null     object
#  4   value   10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df_without['date'].dt.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df_without['date'].dt.month
#
# File ~\PycharmProjects\Data_Scientist_Syntra\.venv\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\PycharmProjects\Data_Scientist_Syntra\.venv\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# ...

# %%
df_with['date'].dt.day_name()
# Out:
# 0       Sunday
# 1       Monday
# 2      Tuesday
# 3    Wednesday
# 4     Thursday
# 5       Friday
# 6     Saturday
# 7       Sunday
# 8       Monday
# 9      Tuesday
# Name: date, dtype: object

# %%
df = pd.read_csv('data/df1.csv', skiprows=2)
df.columns = ['name', 'age']
# Out:
#      Robin  21  Unnamed: 2  02-12-2024  101
# 0      Sam  22          52  03-12-2024  102
# 1    Jamie  23          53  04-12-2024  103
# 2   Taylor  24          54  05-12-2024  104
# 3    Casey  25          55  06-12-2024  105
# 4   Jordan  26          56  07-12-2024  106
# 5      NaN  27          57  08-12-2024  107
# 6    Riley  28          58  09-12-2024  108
# 7  UNKNOWN  29          59  10-12-2024  109

# %% [markdown]
# #### 1.1.2 Special cases
# - different seperator
# - Bad lines
# - diffent encoding

# %% [markdown]
# ### 1.2 Writing

# %% [markdown]
# ## 2. Excel
# ### 2.1 Reading
# - Excel-formules worden niet uitgevoerd, enkel value ingelezen. Zelfde met formatting

# %% [markdown]
# ### 2.2 Writing

# %% [markdown]
# ## 3. SQL
# ### 3.1 Reading

# %% [markdown]
# ### 3.2 Writing

# %% [markdown]
# ## 4. Other formats
