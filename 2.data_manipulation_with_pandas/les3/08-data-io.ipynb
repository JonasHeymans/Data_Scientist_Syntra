# %%
import pandas as pd
import numpy as np
import os
import subprocess

# %%
! python3 --version
! pip3 --version
# Out:
# Python 3.14.0
# pip 24.3.1 from /Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/lib/python3.14/site-packages/pip (python 3.14)

# %%
! which python3
# Out:
# /Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/bin/python3

# %%
cur_dir = os.getcwd()

# %%
subprocess.call(['python3', f'{cur_dir}/gen_files_io.py'])
# Out:
# CSV files generated in ./data/
# Excel demo file generated in ././data/example_excel_demo.xlsx
# 0

# %%
! pip3 install --upgrade pip
! pip3 install openpyxl
! pip3 install sqlalchemy
! pip3 install psycopg2
! pip3 install fastparquet
! pip3 install lxml
# Out:
# WARNING: Ignoring invalid distribution ~ip (/Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/lib/python3.14/site-packages)
# WARNING: Ignoring invalid distribution ~ip (/Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/lib/python3.14/site-packages)
# ...
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# WARNING: Ignoring invalid distribution ~ip (/Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/lib/python3.14/site-packages)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.3.1
#     Uninstalling pip-24.3.1:
#       Successfully uninstalled pip-24.3.1
# WARNING: Ignoring invalid distribution ~ip (/Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/lib/python3.14/site-packages)
# ...
# WARNING: Ignoring invalid distribution ~ip (/Users/inezdemeulenaere/PycharmProjects/Data_Scientist_Syntra/.venv/lib/python3.14/site-packages)
# ...

# %%
password = 'AVNS_ZdDb93Yjx6l0LlnITsX'
conn_str = f"postgresql://avnadmin:{password}@pg-230e9f42-jonas-syntra.b.aivencloud.com:23448/defaultdb?sslmode=require"

# %% [markdown]
# 1. CSV-files
# 2. Excel-files
# 3. Parquet files
# 4. SQL Databases

# %% [markdown]
# ## 1. CSV-files
# Comma seperated files

# %% [markdown]
# ### 1.1 Reading
# #### 1.2 Basic cases
# - data inlezen
# - header kiezen
# - index kiezen
# - omgaan met missing data
# - type casting
# - selective reading

# %% [markdown]
# #### 1.1.2 Special cases
# - different seperator
# - Bad lines
# - diffent encoding

# %% [markdown]
# ### 1.2 Writing

# %% [markdown]
# ## 2. Excel
# ### 2.1 Reading
# - Excel-formules worden niet uitgevoerd, enkel value ingelezen. Zelfde met formatting

# %% [markdown]
# ### 2.2 Writing

# %% [markdown]
# ## 3. SQL
# ### 3.1 Reading

# %% [markdown]
# ### 3.2 Writing

# %% [markdown]
# ## 4. Other formats
