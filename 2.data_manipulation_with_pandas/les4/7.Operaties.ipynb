# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('data/train.csv')

# %% [markdown]
# ### 1. Basis

# %% [markdown]
# ### 2. Info about unique values

# %% [markdown]
# ### 3. Info over opbouw DataFrame

# %% [markdown]
# ### 4. Type conversion

# %% [markdown]
# ### 5. Duplicates

# %%
df = pd.DataFrame({
    'brand': ['Yum Yum', 'Yum Yum', 'Indomie', 'Indomie', 'Indomie'],
    'style': ['cup', 'cup', 'cup', 'pack', 'pack'],
    'rating': [4, 4, 3.5, 15, 5]
})
